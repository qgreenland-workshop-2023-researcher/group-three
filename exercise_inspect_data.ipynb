# %% [markdown]
# Using `magic` to run `gdalinfo` on bash

# %%
nc_filename='airtemp_cmip5_rcp85_mmm_arctic_2006_2055.nc'

# %%
# !gdalinfo $nc_filename
# Out:
# Driver: netCDF/Network Common Data Format
# Files: airtemp_cmip5_rcp85_mmm_arctic_2006_2055.nc
# Size is 512, 512
# Metadata:
#   NC_GLOBAL#acknowledgement=We acknowledge the World Climate Research Programme's Working Group on Coupled Modelling, which is responsible for CMIP, and we thank the climate modeling groups listed below for producing and making available their model output. For CMIP the U.S. Department of Energy's Program for Climate Model Diagnosis and Intercomparison provides coordinating support and led development of software infrastructure in partnership with the Global Organization for Earth System Science Portals. More information on the Coupled Model Intercomparison Project (CMIP5) and the 5th Assessment of the IPCC can be found here: http://cmip-pcmdi.llnl.gov/cmip5/index.html
#   NC_GLOBAL#experiment=rcp85
#   NC_GLOBAL#futuretime=2006-2055
#   NC_GLOBAL#historictime=1956-2005
#   NC_GLOBAL#history=This data file was produced at NOAA/ESRL/PSD with the support of the US Bureau of Reclamation, US Army Corps of Engineers, and CIRES with the esrl.noaa.gov/psd/ipcc/ocn website.
#   NC_GLOBAL#model=ENSMN
#   NC_GLOBAL#variable=tas
# Subdatasets:
#   SUBDATASET_1_NAME=NETCDF:"airtemp_cmip5_rcp85_mmm_arctic_2006_2055.nc":histclim
#   SUBDATASET_1_DESC=[39x360] air_temperature (32-bit floating-point)
#   SUBDATASET_2_NAME=NETCDF:"airtemp_cmip5_rcp85_mmm_arctic_2006_2055.nc":anomaly
#   SUBDATASET_2_DESC=[39x360] air_temperature (32-bit floating-point)
#   SUBDATASET_3_NAME=NETCDF:"airtemp_cmip5_rcp85_mmm_arctic_2006_2055.nc":histstddev
#   SUBDATASET_3_DESC=[39x360] air_temperature (32-bit floating-point)
#   SUBDATASET_4_NAME=NETCDF:"airtemp_cmip5_rcp85_mmm_arctic_2006_2055.nc":varratio
#   SUBDATASET_4_DESC=[39x360] air_temperature (32-bit floating-point)
# Corner Coordinates:
# Upper Left  (    0.0,    0.0)
# Lower Left  (    0.0,  512.0)
# Upper Right (  512.0,    0.0)
# Lower Right (  512.0,  512.0)
# Center      (  256.0,  256.0)

# %%
# !gdalinfo NETCDF:"airtemp_cmip5_rcp85_mmm_arctic_2006_2055.nc":histclim
# Out:
# Driver: netCDF/Network Common Data Format
# Files: airtemp_cmip5_rcp85_mmm_arctic_2006_2055.nc
# Size is 360, 39
# Origin = (0.000000000000000,88.000000000000000)
# Pixel Size = (1.000000000000000,-1.000000000000000)
# Metadata:
#   histclim#associated_files=baseURL: http://cmip-pcmdi.llnl.gov/CMIP5/dataLocation gridspecFile: gridspec_atmos_fx_MIROC-ESM_rcp85_r0i0p0.nc areacella: areacella_fx_MIROC-ESM_rcp85_r0i0p0.nc
#   histclim#average_op_ncl=dim_avg_n function was applied
#   histclim#cell_methods=time: mean
#   histclim#comment=near-surface (usually, 2 meter) air temperature.
#   histclim#description=Ensemble average climate
#   histclim#history=2011-09-13T04:34:46Z altered by CMOR: Treated scalar dimension: 'height'. 2011-09-13T04:34:46Z altered by CMOR: replaced missing value flag (-999) with standard missing value (1e+20). 2011-09-13T04:34:46Z altered by CMOR: Inverted axis: lat.
#   histclim#info=CMIP5 ENSMN historical climate(1956-2005)
#   histclim#interpolation=bilinearly interplated from original model grid to 1x1 grid for intercomparison
#   histclim#long_name=Near-Surface Air Temperature
#   histclim#missing_value=1e+20
#   histclim#original_name=T2
#   histclim#runave_op_ncl=runave_n: nave=12
#   histclim#season=ANN
#   histclim#standard_name=air_temperature
#   histclim#stat=seasonal mean for time period
#   histclim#units=C
#   histclim#_FillValue=1e+20
#   lat#axis=Y
#   lat#long_name=latitude
#   lat#standard_name=latitude
#   lat#units=degrees_north
#   lon#axis=X
#   lon#long_name=longitude
#   lon#standard_name=longitude
#   lon#units=degrees_east
#   NC_GLOBAL#acknowledgement=We acknowledge the World Climate Research Programme's Working Group on Coupled Modelling, which is responsible for CMIP, and we thank the climate modeling groups listed below for producing and making available their model output. For CMIP the U.S. Department of Energy's Program for Climate Model Diagnosis and Intercomparison provides coordinating support and led development of software infrastructure in partnership with the Global Organization for Earth System Science Portals. More information on the Coupled Model Intercomparison Project (CMIP5) and the 5th Assessment of the IPCC can be found here: http://cmip-pcmdi.llnl.gov/cmip5/index.html
#   NC_GLOBAL#experiment=rcp85
#   NC_GLOBAL#futuretime=2006-2055
#   NC_GLOBAL#historictime=1956-2005
#   NC_GLOBAL#history=This data file was produced at NOAA/ESRL/PSD with the support of the US Bureau of Reclamation, US Army Corps of Engineers, and CIRES with the esrl.noaa.gov/psd/ipcc/ocn website.
#   NC_GLOBAL#model=ENSMN
#   NC_GLOBAL#variable=tas
# Corner Coordinates:
# Upper Left  (   0.0000000,  88.0000000)
# Lower Left  (   0.0000000,  49.0000000)
# Upper Right (     360.000,      88.000)
# Lower Right (     360.000,      49.000)
# Center      ( 180.0000000,  68.5000000)
# Band 1 Block=360x1 Type=Float32, ColorInterp=Undefined
#   NoData Value=1e+20
#   Unit Type: C
#   Metadata:
#     associated_files=baseURL: http://cmip-pcmdi.llnl.gov/CMIP5/dataLocation gridspecFile: gridspec_atmos_fx_MIROC-ESM_rcp85_r0i0p0.nc areacella: areacella_fx_MIROC-ESM_rcp85_r0i0p0.nc
#     average_op_ncl=dim_avg_n function was applied
#     cell_methods=time: mean
#     comment=near-surface (usually, 2 meter) air temperature.
#     description=Ensemble average climate
#     history=2011-09-13T04:34:46Z altered by CMOR: Treated scalar dimension: 'height'. 2011-09-13T04:34:46Z altered by CMOR: replaced missing value flag (-999) with standard missing value (1e+20). 2011-09-13T04:34:46Z altered by CMOR: Inverted axis: lat.
#     info=CMIP5 ENSMN historical climate(1956-2005)
#     interpolation=bilinearly interplated from original model grid to 1x1 grid for intercomparison
#     long_name=Near-Surface Air Temperature
#     missing_value=1e+20
#     NETCDF_VARNAME=histclim
#     original_name=T2
#     runave_op_ncl=runave_n: nave=12
#     season=ANN
#     standard_name=air_temperature
#     stat=seasonal mean for time period
#     units=C
#     _FillValue=1e+20

# %% [markdown]
# Using `ncdump -h` to do the same thing

# %%
# !ncdump -h $nc_filename
# Out:
# netcdf airtemp_cmip5_rcp85_mmm_arctic_2006_2055 {
# dimensions:
# 	lat = 39 ;
# 	lon = 360 ;
# variables:
# 	float histclim(lat, lon) ;
# 		histclim:missing_value = 1.e+20f ;
# 		histclim:comment = "near-surface (usually, 2 meter) air temperature." ;
# 		histclim:associated_files = "baseURL: http://cmip-pcmdi.llnl.gov/CMIP5/dataLocation gridspecFile: gridspec_atmos_fx_MIROC-ESM_rcp85_r0i0p0.nc areacella: areacella_fx_MIROC-ESM_rcp85_r0i0p0.nc" ;
# 		histclim:history = "2011-09-13T04:34:46Z altered by CMOR: Treated scalar dimension: \'height\'. 2011-09-13T04:34:46Z altered by CMOR: replaced missing value flag (-999) with standard missing value (1e+20). 2011-09-13T04:34:46Z altered by CMOR: Inverted axis: lat." ;
# 		histclim:cell_methods = "time: mean" ;
# 		histclim:original_name = "T2" ;
# 		histclim:standard_name = "air_temperature" ;
# 		histclim:average_op_ncl = "dim_avg_n function was applied" ;
# 		histclim:runave_op_ncl = "runave_n: nave=12" ;
# 		histclim:long_name = "Near-Surface Air Temperature" ;
# 		histclim:units = "C" ;
# 		histclim:interpolation = "bilinearly interplated from original model grid to 1x1 grid for intercomparison" ;
# 		histclim:stat = "seasonal mean for time period" ;
# 		histclim:season = "ANN" ;
# 		histclim:description = "Ensemble average climate" ;
# 		histclim:_FillValue = 1.e+20f ;
# 		histclim:info = "CMIP5 ENSMN historical climate(1956-2005)" ;
# 	float lat(lat) ;
# 		lat:axis = "Y" ;
# 		lat:standard_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:long_name = "latitude" ;
# 	float lon(lon) ;
# 		lon:axis = "X" ;
# 		lon:standard_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:long_name = "longitude" ;
# 	float anomaly(lat, lon) ;
# 		anomaly:missing_value = 1.e+20f ;
# 		anomaly:comment = "near-surface (usually, 2 meter) air temperature." ;
# 		anomaly:associated_files = "baseURL: http://cmip-pcmdi.llnl.gov/CMIP5/dataLocation gridspecFile: gridspec_atmos_fx_MIROC-ESM_rcp85_r0i0p0.nc areacella: areacella_fx_MIROC-ESM_rcp85_r0i0p0.nc" ;
# 		anomaly:history = "2011-09-13T04:34:46Z altered by CMOR: Treated scalar dimension: \'height\'. 2011-09-13T04:34:46Z altered by CMOR: replaced missing value flag (-999) with standard missing value (1e+20). 2011-09-13T04:34:46Z altered by CMOR: Inverted axis: lat." ;
# 		anomaly:cell_methods = "time: mean" ;
# 		anomaly:original_name = "T2" ;
# 		anomaly:standard_name = "air_temperature" ;
# 		anomaly:average_op_ncl = "dim_avg_n function was applied" ;
# 		anomaly:runave_op_ncl = "runave_n: nave=12" ;
# 		anomaly:long_name = "Near-Surface Air Temperature" ;
# 		anomaly:units = "C" ;
# 		anomaly:interpolation = "bilinearly interplated from original model grid to 1x1 grid for intercomparison" ;
# 		anomaly:stat = "seasonal mean for time period" ;
# 		anomaly:season = "ANN" ;
# 		anomaly:description = "Ensemble average climate" ;
# 		anomaly:_FillValue = 1.e+20f ;
# 		anomaly:info = "CMIP5 ENSMN RCP8.5 anomaly (2006-2055)-(1956-2005)" ;
# 	float histstddev(lat, lon) ;
# 		histstddev:description = "Ensemble average of each model\'s interannual standard deviation" ;
# 		histstddev:season = "ANN" ;
# 		histstddev:stat = "de-trended inter-annual standard deviation for time period" ;
# 		histstddev:interpolation = "bilinearly interplated from original model grid to 1x1 grid for intercomparison" ;
# 		histstddev:units = "C" ;
# 		histstddev:long_name = "Near-Surface Air Temperature" ;
# 		histstddev:runave_op_ncl = "runave_n: nave=12" ;
# 		histstddev:stddev_op_ncl = "dim_stddev_n over dimension(s): time" ;
# 		histstddev:standard_name = "air_temperature" ;
# 		histstddev:original_name = "T2" ;
# 		histstddev:cell_methods = "time: mean" ;
# 		histstddev:history = "2011-09-13T04:34:46Z altered by CMOR: Treated scalar dimension: \'height\'. 2011-09-13T04:34:46Z altered by CMOR: replaced missing value flag (-999) with standard missing value (1e+20). 2011-09-13T04:34:46Z altered by CMOR: Inverted axis: lat." ;
# 		histstddev:associated_files = "baseURL: http://cmip-pcmdi.llnl.gov/CMIP5/dataLocation gridspecFile: gridspec_atmos_fx_MIROC-ESM_rcp85_r0i0p0.nc areacella: areacella_fx_MIROC-ESM_rcp85_r0i0p0.nc" ;
# 		histstddev:comment = "near-surface (usually, 2 meter) air temperature." ;
# 		histstddev:missing_value = 1.e+20f ;
# 		histstddev:average_op_ncl = "dim_avg_n function was applied" ;
# 		histstddev:_FillValue = 1.e+20f ;
# 		histstddev:info = "CMIP5 ENSMN historical standard deviation(1956-2005)" ;
# 	float varratio(lat, lon) ;
# 		varratio:average_op_ncl = "dim_avg_n function was applied" ;
# 		varratio:missing_value = 1.e+20f ;
# 		varratio:comment = "near-surface (usually, 2 meter) air temperature." ;
# 		varratio:associated_files = "baseURL: http://cmip-pcmdi.llnl.gov/CMIP5/dataLocation gridspecFile: gridspec_atmos_fx_MIROC-ESM_rcp85_r0i0p0.nc areacella: areacella_fx_MIROC-ESM_rcp85_r0i0p0.nc" ;
# 		varratio:history = "2011-09-13T04:34:46Z altered by CMOR: Treated scalar dimension: \'height\'. 2011-09-13T04:34:46Z altered by CMOR: replaced missing value flag (-999) with standard missing value (1e+20). 2011-09-13T04:34:46Z altered by CMOR: Inverted axis: lat." ;
# 		varratio:cell_methods = "time: mean" ;
# 		varratio:original_name = "T2" ;
# 		varratio:standard_name = "air_temperature" ;
# 		varratio:stddev_op_ncl = "dim_stddev_n over dimension(s): time" ;
# 		varratio:runave_op_ncl = "runave_n: nave=12" ;
# 		varratio:long_name = "Near-Surface Air Temperature" ;
# 		varratio:units = "K" ;
# 		varratio:interpolation = "bilinearly interplated from original model grid to 1x1 grid for intercomparison" ;
# 		varratio:stat = "de-trended inter-annual standard deviation for time period" ;
# 		varratio:season = "ANN" ;
# 		varratio:description = "Ensemble average of each model\'s interannual standard deviation" ;
# 		varratio:_FillValue = 1.e+20f ;
# 		varratio:info = "CMIP5 ENSMN historical variance ratio(2006-2055)/(1956-2005)" ;
#
# // global attributes:
# 		:model = "ENSMN" ;
# 		:experiment = "rcp85" ;
# 		:variable = "tas" ;
# 		:futuretime = "2006-2055" ;
# 		:historictime = "1956-2005" ;
# 		:history = "This data file was produced at NOAA/ESRL/PSD with the support of the US Bureau of Reclamation, US Army Corps of Engineers, and CIRES with the esrl.noaa.gov/psd/ipcc/ocn website." ;
# 		:acknowledgement = "We acknowledge the World Climate Research Programme\'s Working Group on Coupled Modelling, which is responsible for CMIP, and we thank the climate modeling groups listed below for producing and making available their model output. For CMIP the U.S. Department of Energy\'s Program for Climate Model Diagnosis and Intercomparison provides coordinating support and led development of software infrastructure in partnership with the Global Organization for Earth System Science Portals. More information on the Coupled Model Intercomparison Project (CMIP5) and the 5th Assessment of the IPCC can be found here: http://cmip-pcmdi.llnl.gov/cmip5/index.html" ;
# }

# %% [markdown]
# A python-based approach

# %%
import xarray as xr

ds = xr.open_dataset(nc_filename)
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (lat: 39, lon: 360)
# Coordinates:
#   * lat         (lat) float32 49.5 50.5 51.5 52.5 53.5 ... 84.5 85.5 86.5 87.5
#   * lon         (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
# Data variables:
#     histclim    (lat, lon) float32 ...
#     anomaly     (lat, lon) float32 ...
#     histstddev  (lat, lon) float32 ...
#     varratio    (lat, lon) float32 ...
# Attributes:
#     model:            ENSMN
#     experiment:       rcp85
#     variable:         tas
#     futuretime:       2006-2055
#     historictime:     1956-2005
#     history:          This data file was produced at NOAA/ESRL/PSD with the s...
#     acknowledgement:  We acknowledge the World Climate Research Programme's W...

# %% [markdown]
# does `rioxarray` work?

# %%
print(f'CRS: {ds.rio.crs}')
#print(f'Units: {ds.rio.crs.linear_units}')
print(f'Bounds: {ds.rio.bounds()}')
print(f'Height: {ds.rio.height}')
print(f'Width: {ds.rio.width}')
print(f'Grid pixel resolution: {ds.rio.resolution()}')
# Out:
# CRS: None
# Bounds: (0.0, 49.0, 360.0, 88.0)
# Height: 39
# Width: 360
# Grid pixel resolution: (1.0, 1.0)

# %% [markdown]
# **No!** The dataset does not seem to have an associated CRS...

# %% [markdown]
# **Alternative dataset:** mapped hot springs
#
# dataset from *Colgan, William; Wansing, Agnes, 2021, “Greenland_hot_springs.xlsx”, Greenland Geothermal Heat Flow Database and Map, https://doi.org/10.22008/FK2/F9P03L/OEH5R5, GEUS Dataverse, V2*

# %%
# %%bash
# wget -O Greenland_hot_springs.xlsx  "https://dataverse.geus.dk/api/access/datafile/:persistentId?persistentId=doi:10.22008/FK2/F9P03L/OEH5R5"
# Out:
# --2023-05-23 18:33:40--  https://dataverse.geus.dk/api/access/datafile/:persistentId?persistentId=doi:10.22008/FK2/F9P03L/OEH5R5
# Resolving dataverse.geus.dk (dataverse.geus.dk)... 194.182.159.137
# Connecting to dataverse.geus.dk (dataverse.geus.dk)|194.182.159.137|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11439 (11K) [application/octet-stream]
# Saving to: ‘Greenland_hot_springs.xlsx’
#
#      0K .......... .                                          100% 67.7K=0.2s
#
# 2023-05-23 18:33:41 (67.7 KB/s) - ‘Greenland_hot_springs.xlsx’ saved [11439/11439]

# %%
import pandas as pd

ds_springs = pd.read_excel("Greenland_hot_springs.xlsx",skiprows=2)
ds_springs
# Out:
#                           Name                                  Place  \
# 0                   Storefjord                             South side
# 1               Kap Thermopilæ                         (Store Fjord?)
# 2                Randers fjord                                    NaN
# 3   Janus Island, N hot spring                                    NaN
# 4   Janus Island, S hot spring                                    NaN
# 5              Emanuel Glacier                                    NaN
# 6                      Unarteq                              Kap Tobin
# 7                  Unarterajik                              Kap Tobin
# 8                    Moskilden                               Kap Hope
# 9                   Mosekilden                               Kap Hope
# 10          Römer Fjord, north                      Blosseville coast
# 11          Römer Fjord, south                      Blosseville coast
# 12                  Henry Land                      Blosseville coast
# 13               Knighton Bugt                      Blosseville coast
# 14                  Kap Koster                      Blosseville coast
# 15         Johan Pedersen Bugt                      Blosseville coast
# 16                         NaN                                    NaN
# 17                 Unartorsuaq             Qeqertorsuaq, Disco Island
# 18                     Unartoq      Discofjord, S coast, Disco Island
# 19                Angujartutit         Inner Discofjord, Disco Island
# 20               Tarajungitsoq  Eqalunnguit, Discofjord, Disco Island
# 21                  Unartuarak      Discofjord, N coast, Disco Island
# 22                      Kuanit      Discofjord, N coast, Disco Island
# 23                Qeqertarssuk      Discofjord, N-coast, Disco Island
# 24                Avdlaugissat               Discofjord, Disco Island
# 25                       Qofat                  Disco Island, S coast
# 26                   Puilassoq              Mellemfjord, Disco Island
# 27                  Kildedalen  Kildedalen, mellemfjord, Disco Island
# 28                Unartukavsak              Mellemfjord, Disco Island
# 29                         NaN                                    NaN
# 30                 Ikasagtivaq                           Near Kulusuk
# 31                    Uunartoq                            S-Greenland
#
#            N         W  °C max Q  L/min                        Note  \
# 0     70°04'    21°54'      60      NaN                         NaN
# 1   70°04,5'  21°44,5'    54.2      100               Several vents
# 2     70°58'    21°42'     NaN      NaN                         NaN
# 3   70°52,3'    21°41'     NaN      NaN                         NaN
# 4   70°51,5'    21°40'     NaN      NaN                         NaN
# 5   70°51,6'  21°44,5'     NaN      NaN                         NaN
# 6    70°24,4    21°58'    61.8       40                         NaN
# 7    70°25,2    21°54'   30-33      NaN                         NaN
# 8    70°27,6   22°21,0       2      NaN                         NaN
# 9     70°28'    22°22'      15      NaN     400 m north of Kap Hope
# 10     69°44    23°38'      30      NaN                         NaN
# 11    69°43'    23°42'      58      NaN               Tidal springs
# 12    69°33'    23°41'      38      NaN                         NaN
# 13    69°22'    24°43'      54      NaN  20 springs on a 250 m line
# 14    68°59'    25°30'      41      NaN                         NaN
# 15    68°48'    26°15'      38      NaN                         NaN
# 16       NaN       NaN     NaN      NaN                         NaN
# 17    69°16'    53°34'    16.2  120-180         Gneiss. Salt spring
# 18    69°26'  53°53.5'    11.1   90-120                      Basalt
# 19    69°34'    53°28'  (3-12)      NaN                      Basalt
# 20    69°33'    53°36'    11.5      120         Gneiss. Salt spring
# 21    69°33'    54°00'    14.5      NaN   Basalt. Salt tidal spring
# 22    69°34'    54°18'  (3-12)      NaN                      Basalt
# 23    69°34'    54°34'  (3-12)      NaN                      Basalt
# 24    69°37'    53°51'  (3-12)      NaN                      Basalt
# 25    69°22'    52°47'  (3-12)      NaN                   Sandstone
# 26    69°40'    54°23'    17.6      120                      Basalt
# 27    69°39'    54°11'    14.5      NaN                      Basalt
# 28    69°47'    54°43'    15.4  180-240                      Basalt
# 29       NaN       NaN     NaN      NaN                         NaN
# 30    65°51'    37°29'      25      NaN                         NaN
# 31  60°30,5'    42°20'      42      NaN                         NaN
#
#                                                  Ref.
# 0               Halliday, Kiim-Nielsen and Smart 1974
# 1                               Backlund in Koch 1955
# 2         Geodetik Institute 1:250.000 Map Sheet 70/2
# 3         Geodetik Institute 1:250.000 Map Sheet 70/3
# 4         Geodetik Institute 1:250.000 Map Sheet 70/4
# 5         Geodetik Institute 1:250.000 Map Sheet 70/5
# 6   A. Pedersen 1926, T.B. Pedersen 1931, Hartshor...
# 7                A. Pedersen 1926, Watt, S. W. (1971)
# 8                A. Pedersen 1926, T.B. Pedersen 1929
# 9   Watt, S. W. (1971). Datagrundlag for kemiske s...
# 10             Hallliday, Kiim-Nielsen and Smart 1974
# 11             Hallliday, Kiim-Nielsen and Smart 1974
# 12             Hallliday, Kiim-Nielsen and Smart 1974
# 13             Hallliday, Kiim-Nielsen and Smart 1974
# 14             Hallliday, Kiim-Nielsen and Smart 1974
# 15             Hallliday, Kiim-Nielsen and Smart 1974
# 16                                                NaN
# 17                    Hjartarson and Ármannsson 2005.
# 18                    Hjartarson and Ármannsson 2005.
# 19                              Kristensen, R.M. 1987
# 20                    Hjartarson and Ármannsson 2005.
# 21                    Hjartarson and Ármannsson 2005.
# 22                              Kristensen, R.M. 1987
# 23                              Kristensen, R.M. 1987
# 24                              Kristensen, R.M. 1987
# 25                              Kristensen, R.M. 1987
# 26                    Hjartarson and Ármannsson 2005.
# 27                              Kristensen, R.M. 1987
# 28                    Hjartarson and Ármannsson 2005.
# 29                                                NaN
# 30                                                NaN
# 31                     Hjartarson and Ármannsson 2015
